# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Bigbazaar_sales_data.csv')

# %%
data.head(20)
# Out:
#    Item_Identifier  Item_Weight  Item_Visibility  Year Outlet_Identifier  \
# 0            FDA15        9.300         0.016047    17            OUT049
# 1            DRC01        5.920         0.019278     7            OUT018
# 2            FDN15       17.500         0.016760    17            OUT049
# 3            FDX07       19.200         0.022930    18            OUT010
# 4            NCD19        8.930         0.014670    29            OUT013
# 5            FDP36       10.395         0.091294     7            OUT018
# 6            FDO10       13.650         0.012741    29            OUT013
# 7            FDP10       19.000         0.127470    31            OUT027
# 8            FDH17       16.200         0.016687    14            OUT045
# 9            FDU28       19.200         0.094450     9            OUT017
# 10           FDY07       11.800         0.121880    17            OUT049
# 11           FDA03       18.500         0.045464    19            OUT046
# ...

# %%
data.tail(20)
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Year Outlet_Identifier  \
# 14184           DRG37       16.200         0.022472    31            OUT027
# 14185           FDK22        9.800         0.026234     9            OUT017
# 14186           DRH36       16.200         0.033516     7            OUT018
# 14187           DRC36       13.000         0.045168     7            OUT018
# 14188           DRE03       19.600         0.024110    31            OUT027
# 14189           FDF34        9.300         0.014019    19            OUT046
# 14190           FDZ22        9.395         0.045270    19            OUT046
# 14191           FDC44       15.600         0.288892    18            OUT010
# 14192           FDN31       11.500         0.072529    31            OUT027
# 14193           FDO03       10.395         0.037092     9            OUT017
# 14194           FDA01       15.000         0.054463    17            OUT049
# ...

# %%
data.size
# Out:
# 184652

# %%
data.shape
# Out:
# (14204, 13)

# %%
data.describe()
# Out:
#         Item_Weight  Item_Visibility          Year      Item_MRP  \
# count  14204.000000     14204.000000  14204.000000  14204.000000
# mean      12.793380         0.070458     18.169319    141.004977
# std        4.651716         0.050086      8.371664     62.086938
# min        4.555000         0.003575      7.000000     31.290000
# 25%        8.710000         0.031381     12.000000     94.012000
# 50%       12.600000         0.058064     17.000000    142.247000
# 75%       16.750000         0.098042     29.000000    185.855600
# max       21.350000         0.328391     31.000000    266.888400
#
#         Outlet_Size  Item_Outlet_Sales  Converted Sales
# count  14204.000000       14204.000000     14204.000000
# mean       2.170867        2181.583015         1.418029
# std        0.600306        1548.842827         1.006749
# min        1.000000       -1363.321822        -0.886000
# 25%        2.000000        1001.363200         0.651000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Item_Identifier       14204 non-null  object
#  1   Item_Weight           14204 non-null  float64
#  2   Item_Visibility       14204 non-null  float64
#  3   Year                  14204 non-null  int64
#  4   Outlet_Identifier     14204 non-null  object
#  5   Item_Type             14204 non-null  object
#  6   Item_MRP              14204 non-null  float64
#  7   MRP_Level             14204 non-null  object
#  8   Outlet_Size           14204 non-null  int64
#  9   Outlet_Location_Type  14204 non-null  object
#  10  Outlet_Type           14204 non-null  object
#  11  Item_Outlet_Sales     14204 non-null  float64
#  12  Converted Sales       14204 non-null  float64
# dtypes: float64(5), int64(2), object(6)
# memory usage: 1.4+ MB

# %%
data.mean()
# Out:
# C:\Users\ADAPAA~1\AppData\Local\Temp/ipykernel_21552/531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Item_Weight            12.793380
# Item_Visibility         0.070458
# Year                   18.169319
# Item_MRP              141.004977
# Outlet_Size             2.170867
# Item_Outlet_Sales    2181.583015
# Converted Sales         1.418029
# dtype: float64

# %%
data.mode()
# Out:
#     Item_Identifier  Item_Weight  Item_Visibility  Year Outlet_Identifier  \
# 0             DRA24         17.6          0.12188  31.0            OUT027
# 1             DRA59          NaN              NaN   NaN               NaN
# 2             DRB25          NaN              NaN   NaN               NaN
# 3             DRC25          NaN              NaN   NaN               NaN
# 4             DRC27          NaN              NaN   NaN               NaN
# ..              ...          ...              ...   ...               ...
# 499           NCY29          NaN              NaN   NaN               NaN
# 500           NCY41          NaN              NaN   NaN               NaN
# 501           NCZ30          NaN              NaN   NaN               NaN
# 502           NCZ42          NaN              NaN   NaN               NaN
# 503           NCZ54          NaN              NaN   NaN               NaN
#
#                  Item_Type  Item_MRP MRP_Level  Outlet_Size  \
# ...

# %%
data.isnull()
# Out:
#        Item_Identifier  Item_Weight  Item_Visibility   Year  \
# 0                False        False            False  False
# 1                False        False            False  False
# 2                False        False            False  False
# 3                False        False            False  False
# 4                False        False            False  False
# ...                ...          ...              ...    ...
# 14199            False        False            False  False
# 14200            False        False            False  False
# 14201            False        False            False  False
# 14202            False        False            False  False
# 14203            False        False            False  False
#
#        Outlet_Identifier  Item_Type  Item_MRP  MRP_Level  Outlet_Size  \
# 0                  False      False     False      False        False
# 1                  False      False     False      False        False
# ...

# %%
data.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Weight             0
# Item_Visibility         0
# Year                    0
# Outlet_Identifier       0
# Item_Type               0
# Item_MRP                0
# MRP_Level               0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# Item_Outlet_Sales       0
# Converted Sales         0
# dtype: int64

# %%
data.median()
# Out:
# C:\Users\ADAPAA~1\AppData\Local\Temp/ipykernel_21552/4184645713.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.median()
# Item_Weight            12.600000
# Item_Visibility         0.058064
# Year                   17.000000
# Item_MRP              142.247000
# Outlet_Size             2.000000
# Item_Outlet_Sales    1966.987402
# Converted Sales         1.278500
# dtype: float64

# %%
data.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Visibility', 'Year',
#        'Outlet_Identifier', 'Item_Type', 'Item_MRP', 'MRP_Level',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',
#        'Item_Outlet_Sales', 'Converted Sales'],
#       dtype='object')

# %%
sns.pairplot(data)

# %%
sns.boxplot(x=data['Item_Outlet_Sales'])
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales'>

# %%
sns.kdeplot(x='Item_Outlet_Sales',data = data,hue = 'MRP_Level')
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdBu')
plt.show()

# %%
sns.violinplot(x=data['Item_Outlet_Sales'], y=data['Converted Sales'])
